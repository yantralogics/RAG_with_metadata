# %%
import wikipediaapi
from docx import Document

# Function to fetch Wikipedia article content
def fetch_wikipedia_article(title):
    user_agent = "MyProjectName(yantralogics@outlook.com)"
    wiki_wiki = wikipediaapi.Wikipedia(user_agent, 'en')
    page = wiki_wiki.page(title)
    if page.exists():
        return page.text
    else:
        return None

# Function to save content to MS Word document
def save_to_word_document(content, output_file):
    doc = Document()
    doc.add_paragraph(content)
    doc.save(output_file)

# Example usage
if __name__ == "__main__":
    # Replace 'Python (programming language)' with the title of the Wikipedia article you want to fetch
    article_title = 'Linkin Park'
    # Replace 'output.docx' with the desired name for the output Word document
    output_file = 'temp_data/output.docx'

    # Fetch Wikipedia article content
    article_content = fetch_wikipedia_article(article_title)
    
    if article_content:
        # Save content to MS Word document
        save_to_word_document(article_content, output_file)
        print("Wikipedia article saved as", output_file)
    else:
        print("Wikipedia article not found.")
# Out:
# Wikipedia article saved as temp_data/output.docx

# %% [markdown]
# # Reading Microsoft Documents with Python
#
# Target condition:
#  - Read .docx document text with available metadata
#     - Headings
#     - Paragraphs
#     - Sections
#     - Pages
#
#
# Things to figure out:
# - Using python-docx library is easy enough to read MS word documents.
# - The paragraph level information is easy enough to parse.
# - Sections and subsections are a bit tricky unless specified by the document itself.
#
#
# How to detect the sections and subsections:
# - Try using paragraph properties.
# - Look at the fontsize of the majority of the texts and set as "normal" anything outside of that would be a section heading text.
#
# Use of unstructured library:
# - partition_docx is avaialble to use out of the box

# %%
user_agent = "MyProjectName(yantralogics@outlook.com)"
wiki_wiki = wikipediaapi.Wikipedia(user_agent, 'en',extract_format=wikipediaapi.ExtractFormat.WIKI)
page = wiki_wiki.page('Linkin Park')

# %%
import pandas as pd
sections = []
dat =[]
for s in page.sections:
    sections.append(s.title)
    dat.append(s.text)

print(sections)
dat2=(page.section_by_title('Summary').text)

#df  = pd.DataFrame([sections,dat])
print(dat2)
# Out:
# ['History', 'Philanthropy', 'Musical style and influences', 'Legacy', 'Band members', 'Discography', 'Awards and nominations', 'Concert tours', 'See also', 'Notes', 'References', 'External links']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 9
#       6     dat.append(s.text)
#       8 print(sections)
# ----> 9 dat2=(page.section_by_title('Summary').text)
#      11 #df  = pd.DataFrame([sections,dat])
#      12 print(dat2)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df.head()
# Out:
#         0                                                  1   \
# 0  History                                       Philanthropy
# 1           On January 19, 2010, Linkin Park released a ne...
#
#                                                   2   \
# 0                       Musical style and influences
# 1  Linkin Park combines elements of metal, indust...
#
#                                                   3             4   \
# 0                                             Legacy  Band members
# 1  Linkin Park has sold more than 100 million rec...      Timeline
#
#                                                   5                       6   \
# 0                                        Discography  Awards and nominations
# 1  Studio albums\n\nHybrid Theory (2000)\nMeteora...
#
#                                                   7   \
# 0                                      Concert tours
# 1  Headlining\n\nHybrid Theory World Tour (2001)\...
#
#                                                   8      9           10  \
# 0                                           See also  Notes  References
# 1  List of best-selling music artists\nList of be...
#
#                                         11
# 0                           External links
# 1  \nOfficial website \nmusicforrelief.org

# %%
from docx import Document

def read_docx(file_path):
    doc = Document(file_path)
    text = ' '.join([paragraph.text for paragraph in doc.paragraphs])
    return text

# Usage
file_path = 'temp_data/output.docx'
Doc1 = Document(file_path)
print(Doc1)
#text = read_docx(file_path)
#print(text)
# Out:
# <docx.document.Document object at 0x113a819c0>

# %%
from docx import Document
import os

# Function to extract metadata from a Word document
def extract_metadata(docx_file):
    doc = Document(docx_file)

    # Extract file name
    file_name = os.path.basename(docx_file)

    # Extract paragraphs
    paragraphs = [p.text for p in doc.paragraphs]

    # Extract headings
    headings = []
    for paragraph in doc.paragraphs:
        if paragraph.style.name.startswith('Heading'):
            headings.append(paragraph.text)

    # Extract page numbers (not directly supported in python-docx)
    # You may need to use additional libraries or techniques to get page numbers.

    return {
        "file_name": file_name,
        "paragraphs": paragraphs,
        "headings": headings
        # Add more metadata as needed
    }

# Example usage
if __name__ == "__main__":
    # Replace 'your_word_document.docx' with the path to your Word document
    docx_file = 'temp_data/output_V2.docx'
    
    metadata = extract_metadata(docx_file)
    print("File Name:", metadata["file_name"])
    print("Paragraphs:", metadata["paragraphs"])
    print("Headings:", metadata["headings"])
# Out:
# File Name: output_V2.docx
# Paragraphs: ['Summary', 'Linkin Park is an American rock band from Agoura Hills, California. The band\'s lineup consists of vocalist/rhythm guitarist/keyboardist Mike Shinoda, lead guitarist Brad Delson, bassist Dave Farrell, DJ/turntablist Joe Hahn, and drummer Rob Bourdon, with vocalist Chester Bennington also part of the band until his death in 2017. Categorized as alternative rock, Linkin Park\'s earlier music spanned a fusion of heavy metal and hip hop, while their later music features more electronica and pop elements.\nFormed in 1996, Linkin Park rose to international fame with their debut studio album, Hybrid Theory (2000), which became certified Diamond by the Recording Industry Association of America (RIAA). Released during the peak of the nu metal scene, the album\'s singles\' heavy airplay on MTV led the singles "One Step Closer", "Crawling", and "In the End" all to chart highly on the US Mainstream Rock chart. The lattermost also crossed over to the #2 spot on the nation\'s Billboard Hot 100. Their second album, Meteora (2003), continued the band\'s success. The band explored experimental sounds on their third album, Minutes to Midnight (2007). By the end of the decade, Linkin Park was among the most successful and popular rock acts.\nThe band continued to explore a wider variation of musical types on their fourth album, A Thousand Suns (2010), layering their music with more electronic sounds. The band\'s fifth album, Living Things (2012), combined musical elements from all of their previous records. Their sixth album, The Hunting Party (2014), returned to a heavier rock sound, while their seventh album, One More Light (2017), was a substantially more pop-oriented record. Linkin Park went on an indefinite hiatus following the suicide of longtime lead vocalist Bennington in July 2017 and have not recorded or toured since then. Since Bennington\'s death, they have only released 20th-anniversary editions of their first two studio albums, as well as a greatest hits album, Papercuts, in 2024.\nLinkin Park is among both the best-selling bands of the 21st century and the world\'s best-selling music artists, having sold over 100 million records worldwide. They have won two Grammy Awards, six American Music Awards, two Billboard Music Awards, four MTV Video Music Awards, 10 MTV Europe Music Awards, and three World Music Awards. In 2003, MTV2 named Linkin Park the sixth-greatest band of the music video era and the third-best of the new millennium. Billboard ranked Linkin Park No. 19 on the Best Artists of the Decade list. In 2012, the band was voted as the greatest artist of the 2000s in a Bracket Madness poll on VH1. In 2014, the band was declared as "The Biggest Rock Band in the World Right Now" by Kerrang!.\n\nHistory\n1996–2000: early years\nLinkin Park was founded by three high school friends: Mike Shinoda, Rob Bourdon, and Brad Delson. The three attended Agoura High School in Agoura Hills, California, a suburb of Los Angeles. After graduating from high school, the three began to take their musical interests more seriously, recruiting Joe Hahn, Dave "Phoenix" Farrell, and Mark Wakefield to perform in their band, then called Xero. Though limited in resources, the band began recording and producing songs within Shinoda\'s makeshift bedroom studio in 1996, resulting in a four-track demo album, entitled Xero, released in November 1997. Xero performed their first show on November 14, opening for SX-10 and System of a Down at the Whisky a Go Go, a nightclub in West Hollywood. Delson introduced the band to Jeff Blue, the vice president of A&R for Zomba Music, whom he had interned for in college. Blue offered the band constructive criticism to catch the attention of record labels. Blue himself was impressed with Xero after watching them play a live show in 1998, but believed the band needed a different vocalist. Tensions and frustration within the band grew after they failed to land a record deal. The lack of success and stale ...
# Headings: ['Summary']

# %%
from unstructured.partition.docx import partition_docx


with open("temp_data/test-plan-template.docx", "rb") as f:
    elements = partition_docx(file=f)

# %%
import json
element_dict = [el.to_dict() for el in elements]
example_output = json.dumps(element_dict, indent=2)
print(example_output)
# Out:
# [
#   {
#     "type": "Header",
#     "element_id": "95a5ad919c15e641149a77cf3ccd67a4",
#     "text": "Test Plan\nProject Title:\n___________________________________________________________________",
#     "metadata": {
#       "category_depth": 0,
#       "header_footer_type": "primary",
#       "languages": [
#         "eng"
#       ],
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "6af208292f6e60d8ac7c1400e31f08db",
#     "text": "Purpose of the Document",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Purpose of the Document"
#       ],
#       "emphasized_text_tags": [
#         "b"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "cd4d4ab739612ea05563cd5eb2ed0696",
#     "text": "Use the Test Plan document to describe the testing approach and overall framework that will drive the testing of the project.  ",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "6af208292f6e60d8ac7c1400e31f08db",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "41967af4b1a10a5dd14ede5794312e08",
#     "text": "Template Instructions",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Template Instructions",
#         "Template Instructions"
#       ],
#       "emphasized_text_tags": [
#         "b",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "e518811f7c8d468723232b3bc1f4e618",
#     "text": "Note that the information in italics is guidelines for documenting testing efforts and activities.  To adopt this template, delete all italicized instructions and modify as appropriate",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Note that the information in italics is guidelines",
#         "for",
#         "documenting",
#         "testing efforts and activities",
#         ".  To adopt",
#         "this template",
#         ", delete all italicized i",
#         "nstructions and modify",
#         "as appropriate"
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "41967af4b1a10a5dd14ede5794312e08",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "b605350bc00209520b7cd8f546322663",
#     "text": "Introduction",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "fc944e84ca41a855efb3ee089b98c93e",
#     "text": "  Purpose",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "b605350bc00209520b7cd8f546322663",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "fd22a255d97a5d34fac39ea10d843fa8",
#     "text": "Provide a summary of the test strategy, test approach, execution strategy and test management.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Provide",
#         "a summary",
#         "of the test strategy, test approach, execution strategy and test management."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fc944e84ca41a855efb3ee089b98c93e",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "fbd7efbe4325f66157aba1b03280d502",
#     "text": "  Project Overview",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "b605350bc00209520b7cd8f546322663",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "5cb14d801a287844d163469839940e0b",
#     "text": "A summary of the project, product, solution being tested.  ",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "A",
#         "summary of the project, product, solution being tested."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fbd7efbe4325f66157aba1b03280d502",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "5d9d0112647b90f1a79d3202b86d7d7c",
#     "text": "  Scope",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "2fd7440c5fe671120be32f9630f54ff8",
#     "text": "  In-Scope",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "5d9d0112647b90f1a79d3202b86d7d7c",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "f39080175a84b9df75febeafef56f5ee",
#     "text": "Describes what is being tested, such as all the functions/features of a specific project/product/solution.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "D",
#         "escribes what is being tested, such as all the functions",
#         "/features",
#         "of a specific",
#         "project/product/solution."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i",
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "2fd7440c5fe671120be32f9630f54ff8",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "91a8b7493327ad2edadbcdfec477058d",
#     "text": "Specify interfaces, process, workflow, vendor integration.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Specify",
#         "interfaces,",
#         "process, workflow, vendor integration."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "96fd1add525e0f586a4dc7cad21f2f2c",
#     "text": "  Out-of-Scope",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "91a8b7493327ad2edadbcdfec477058d",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "87639f55aedd3c814093b7f812e1ec97",
#     "text": "Identify all features and combinations of features which will not be tested and the reasons.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Identify all features and combinations of features which will not be tested and the reasons."
#       ],
#       "emphasized_text_tags": [
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "96fd1add525e0f586a4dc7cad21f2f2c",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "fe67395de374dbd1479f760f52ae38ac",
#     "text": "  Testing Strategy",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "e868d904f3f8fc870c1156ad0fd150e6",
#     "text": "  Test Objectives",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fe67395de374dbd1479f760f52ae38ac",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "f5ef6248ea11132d891032b1922f598e",
#     "text": "Describe the objectives.  Define tasks and responsibilities.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Describe the objec",
#         "tives.  Define",
#         "tasks and responsibilities",
#         "."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "e868d904f3f8fc870c1156ad0fd150e6",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "df5edd0331fbd267032e9986095bd0ae",
#     "text": "Example:  ",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Example:"
#       ],
#       "emphasized_text_tags": [
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "20de70a12a558281d89a11257af00606",
#     "text": "The registrar office should test the registration workflow.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "The registrar office should test the registration workflow."
#       ],
#       "emphasized_text_tags": [
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "df5edd0331fbd267032e9986095bd0ae",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "24000a8944089ed12099314d997fb22d",
#     "text": "  Test Assumptions",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "df5edd0331fbd267032e9986095bd0ae",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "5d04387e9a1f9dac5d1b69314b170dc6",
#     "text": "List the key assumptions of the project and the test plan.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "List",
#         "the key assumptions of the project and the test plan."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "24000a8944089ed12099314d997fb22d",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "4ae71e5edc85edab11b79d31e3e1590e",
#     "text": "  Data Approach",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "df5edd0331fbd267032e9986095bd0ae",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "dbca7ac7cacb0dccb7a1660e150406ca",
#     "text": " Describe the approach on the test data maintained in QA environments for functional and user acceptance testing.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Describe the approach on the test data maintained in QA environments for functional and user acceptance testing."
#       ],
#       "emphasized_text_tags": [
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "4ae71e5edc85edab11b79d31e3e1590e",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "212385bb0ddd60a1ea2d7caaf7b4178b",
#     "text": "  Level of Testing",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "df5edd0331fbd267032e9986095bd0ae",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ea7dd9dd931fd16df58ca27d4f237e61",
#     "text": "List the types of testing to be performed.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "List the types of testing to be performed"
#       ],
#       "emphasized_text_tags": [
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "212385bb0ddd60a1ea2d7caaf7b4178b",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "a44e55f08286f5ff5cb6ca58fde619a8",
#     "text": "Test Type Description Responsible Parties",
#     "metadata": {
#       "emphasized_text_contents": [
#         "Test Type",
#         "Description",
#         "Responsible Parties"
#       ],
#       "emphasized_text_tags": [
#         "b",
#         "b",
#         "b"
#       ],
#       "page_number": 1,
#       "text_as_html": "<table>\n<thead>\n<tr><th>Test Type  </th><th>Description  </th><th>Responsible Parties  </th></tr>\n</thead>\n<tbody>\n<tr><td>           </td><td>             </td><td>                     </td></tr>\n<tr><td>           </td><td>             </td><td>                     </td></tr>\n<tr><td>           </td><td>             </td><td>                     </td></tr>\n<tr><td>           </td><td>             </td><td>                     </td></tr>\n</tbody>\n</table>",
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "212385bb0ddd60a1ea2d7caaf7b4178b",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "584b654252596ef6a70cabcf4279b981",
#     "text": "  Unit Testing",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "df5edd0331fbd267032e9986095bd0ae",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "950153245d73824a06cb352e0a2e2628",
#     "text": "Specify what features are to be tested.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Specify",
#         "what features are to be tested."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "584b654252596ef6a70cabcf4279b981",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "fd5069b81dfead8b9e691f934037a546",
#     "text": "Participants:  ",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "47241851ba19d641081d81bb0a723ad1",
#     "text": "Tester\u2019s Name Department/ Area Role Test Manager Test Lead Test Analyst",
#     "metadata": {
#       "emphasized_text_contents": [
#         "Tester\u2019s Name",
#         "Department/ Area",
#         "Role"
#       ],
#       "emphasized_text_tags": [
#         "b",
#         "b",
#         "b"
#       ],
#       "page_number": 1,
#       "text_as_html": "<table>\n<thead>\n<tr><th>Tester\u2019s Name  </th><th>Department/ Area  </th><th>Role        </th></tr>\n</thead>\n<tbody>\n<tr><td>               </td><td>                  </td><td>Test Manager</td></tr>\n<tr><td>               </td><td>                  </td><td>Test Lead   </td></tr>\n<tr><td>               </td><td>                  </td><td>Test Analyst</td></tr>\n</tbody>\n</table>",
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fd5069b81dfead8b9e691f934037a546",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "6aff7a3bbf581c4d33f8bebcda425c2a",
#     "text": "  Functional Testing",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fd5069b81dfead8b9e691f934037a546",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "950153245d73824a06cb352e0a2e2628",
#     "text": "Specify what features are to be tested.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Specify",
#         "what features are to be tested."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "6aff7a3bbf581c4d33f8bebcda425c2a",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "fd5069b81dfead8b9e691f934037a546",
#     "text": "Participants:  ",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "47241851ba19d641081d81bb0a723ad1",
#     "text": "Tester\u2019s Name Department/ Area Role Test Manager Test Lead Test Analyst",
#     "metadata": {
#       "emphasized_text_contents": [
#         "Tester\u2019s Name",
#         "Department/ Area",
#         "Role"
#       ],
#       "emphasized_text_tags": [
#         "b",
#         "b",
#         "b"
#       ],
#       "page_number": 1,
#       "text_as_html": "<table>\n<thead>\n<tr><th>Tester\u2019s Name  </th><th>Department/ Area  </th><th>Role        </th></tr>\n</thead>\n<tbody>\n<tr><td>               </td><td>                  </td><td>Test Manager</td></tr>\n<tr><td>               </td><td>                  </td><td>Test Lead   </td></tr>\n<tr><td>               </td><td>                  </td><td>Test Analyst</td></tr>\n</tbody>\n</table>",
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fd5069b81dfead8b9e691f934037a546",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "fcd2abf6a7a585fac821fb556c1790c5",
#     "text": "  User Acceptance Testing",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fd5069b81dfead8b9e691f934037a546",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "950153245d73824a06cb352e0a2e2628",
#     "text": "Specify what features are to be tested.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Specify",
#         "what features are to be tested."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fcd2abf6a7a585fac821fb556c1790c5",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "fd5069b81dfead8b9e691f934037a546",
#     "text": "Participants:  ",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "47241851ba19d641081d81bb0a723ad1",
#     "text": "Tester\u2019s Name Department/ Area Role Test Manager Test Lead Test Analyst",
#     "metadata": {
#       "emphasized_text_contents": [
#         "Tester\u2019s Name",
#         "Department/ Area",
#         "Role"
#       ],
#       "emphasized_text_tags": [
#         "b",
#         "b",
#         "b"
#       ],
#       "page_number": 1,
#       "text_as_html": "<table>\n<thead>\n<tr><th>Tester\u2019s Name  </th><th>Department/ Area  </th><th>Role        </th></tr>\n</thead>\n<tbody>\n<tr><td>               </td><td>                  </td><td>Test Manager</td></tr>\n<tr><td>               </td><td>                  </td><td>Test Lead   </td></tr>\n<tr><td>               </td><td>                  </td><td>Test Analyst</td></tr>\n</tbody>\n</table>",
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fd5069b81dfead8b9e691f934037a546",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "c1d8c5bb4c7783daad5cf4e53cdddfcb",
#     "text": "  Regression Testing ",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fd5069b81dfead8b9e691f934037a546",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "950153245d73824a06cb352e0a2e2628",
#     "text": "Specify what features are to be tested.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Specify",
#         "what features are to be tested."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "c1d8c5bb4c7783daad5cf4e53cdddfcb",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "fd5069b81dfead8b9e691f934037a546",
#     "text": "Participants:  ",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "47241851ba19d641081d81bb0a723ad1",
#     "text": "Tester\u2019s Name Department/ Area Role Test Manager Test Lead Test Analyst",
#     "metadata": {
#       "emphasized_text_contents": [
#         "Tester\u2019s Name",
#         "Department/ Area",
#         "Role"
#       ],
#       "emphasized_text_tags": [
#         "b",
#         "b",
#         "b"
#       ],
#       "page_number": 1,
#       "text_as_html": "<table>\n<thead>\n<tr><th>Tester\u2019s Name  </th><th>Department/ Area  </th><th>Role        </th></tr>\n</thead>\n<tbody>\n<tr><td>               </td><td>                  </td><td>Test Manager</td></tr>\n<tr><td>               </td><td>                  </td><td>Test Lead   </td></tr>\n<tr><td>               </td><td>                  </td><td>Test Analyst</td></tr>\n</tbody>\n</table>",
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "fd5069b81dfead8b9e691f934037a546",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "d3b0e2277c8a0a1b353791c229106808",
#     "text": "Execution Strategy",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "19cec38aacf802f8c9e9fddf7a206042",
#     "text": "  Entry Criteria",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "d3b0e2277c8a0a1b353791c229106808",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "54fa41e31a97d4187e081ca2a8863120",
#     "text": "The entry criteria refer to the desirable conditions in order to start test execution",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "The entry criteria refer to the desirable conditions in",
#         "order to start test execution"
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "19cec38aacf802f8c9e9fddf7a206042",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "5ed0a50e4b2c028d1581d6ed7d0b8cbb",
#     "text": "Entry criteria are flexible benchmarks. If they are not met, the test team will assess the risk, identify mitigation actions and provide a recommendation.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Entry",
#         "criteria are flexible benchmarks. If they are not met, the test team will assess the risk, identify mitigation actions and provide a recommendation."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "19cec38aacf802f8c9e9fddf7a206042",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "b5a7a6c978fdc9ee160fbfbf77380f71",
#     "text": "Entry Criteria Test Team Technical Team Notes Test environment(s) is available Test data is available Code has been merged successfully Development has completed unit testing Test scripts are completed, reviewed and approved by the Project Team",
#     "metadata": {
#       "emphasized_text_contents": [
#         "Entry",
#         "Criteria",
#         "Test Team",
#         "Technical Team",
#         "Notes",
#         "Test e",
#         "nvironment(s) is available",
#         "Test data is available",
#         "Code has been merged successfully",
#         "Development has completed unit testing",
#         "Test scripts are completed, reviewed and approved by the Project Team"
#       ],
#       "emphasized_text_tags": [
#         "b",
#         "b",
#         "b",
#         "b",
#         "b",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "text_as_html": "<table>\n<thead>\n<tr><th>Entry Criteria                                                       </th><th>Test Team  </th><th>Technical Team  </th><th>Notes  </th></tr>\n</thead>\n<tbody>\n<tr><td>Test environment(s) is available                                     </td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>Test data is available                                               </td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>Code has been merged successfully                                    </td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>Development has completed unit testing                               </td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>Test scripts are completed, reviewed and approved by the Project Team</td><td>           </td><td>                </td><td>       </td></tr>\n</tbody>\n</table>",
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "19cec38aacf802f8c9e9fddf7a206042",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "266540de674e35fcfe984dd417b770d7",
#     "text": "  Exit criteria",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "d3b0e2277c8a0a1b353791c229106808",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "5c67393d661bbbe3e404076b50cd43e0",
#     "text": "The exit criteria are the desirable conditions that need to be met in order proceed with the implementation.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "The exit criteria are the desirable conditions that need to be met in order proceed with the implementation."
#       ],
#       "emphasized_text_tags": [
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "266540de674e35fcfe984dd417b770d7",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "7697cd12724a87f84fa00dc3ecb46b30",
#     "text": "Exit criteria are flexible benchmarks. If they are not met, the test team will assess the risk, identify mitigation actions and provide a recommendation.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "E",
#         "xit criteria are flexible benchmarks. If they are not met, the test team will assess the risk, identify mitigation actions and provide a recommendation."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "266540de674e35fcfe984dd417b770d7",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "bd3bf3f7a1abaa4fdcbb4318207bcd3b",
#     "text": "Exit Criteria Test Team Technical Team Notes 100% Test Scripts executed 90% pass rate of Test Scripts No open Critical and High severity defects All remaining defects are either cancelled or documented as Change Requests for a future release All expected and actual results are captured and documented with the test script All test metrics collected based on reports from daily and Weekly Status reports All defects logged in  Defect Tracker/Spreadsheet Test environment cleanup completed and a new back up of the environment",
#     "metadata": {
#       "emphasized_text_contents": [
#         "Exit Criteria",
#         "Test Team",
#         "Technical Team",
#         "Notes",
#         "100% Test Scripts executed",
#         "90",
#         "% pass rate of Test Scripts",
#         "No open Critical and High severity defects",
#         "All remaining defects are either cancelled or documented as Change Requests for a future release",
#         "All expected and actual results are captured and documented with the test script",
#         "All test metrics collected based on reports from d",
#         "aily and Weekly Status reports",
#         "All defects logged in",
#         "Defect Tracker",
#         "/Spreadsheet",
#         "Test environment cleanup completed and a new back up of the environment"
#       ],
#       "emphasized_text_tags": [
#         "b",
#         "b",
#         "b",
#         "b",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "text_as_html": "<table>\n<thead>\n<tr><th>Exit Criteria                                                                                   </th><th>Test Team  </th><th>Technical Team  </th><th>Notes  </th></tr>\n</thead>\n<tbody>\n<tr><td>100% Test Scripts executed                                                                      </td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>90% pass rate of Test Scripts                                                                   </td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>No open Critical and High severity defects                                                      </td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>All remaining defects are either cancelled or documented as Change Requests for a future release</td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>All expected and actual results are captured and documented with the test script                </td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>All test metrics collected based on reports from daily and Weekly Status reports                </td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>All defects logged in  Defect Tracker/Spreadsheet                                               </td><td>           </td><td>                </td><td>       </td></tr>\n<tr><td>Test environment cleanup completed and a new back up of the environment                         </td><td>           </td><td>                </td><td>       </td></tr>\n</tbody>\n</table>",
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "266540de674e35fcfe984dd417b770d7",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "da239340b265ec3de6ddbfa1f375015c",
#     "text": "  Validation and Defect Management",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "d3b0e2277c8a0a1b353791c229106808",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "be47f6c06691c82cf4466a53b0028e7d",
#     "text": "Specify how test cases/test scenarios should be validated",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Specify how test cases/test scenarios should be validated"
#       ],
#       "emphasized_text_tags": [
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "da239340b265ec3de6ddbfa1f375015c",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "977e001dc6029e386c99904e48aa9226",
#     "text": "Specify how defect should be managed",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Specify how defect should be managed"
#       ],
#       "emphasized_text_tags": [
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "da239340b265ec3de6ddbfa1f375015c",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "92d3c36eab9b101f7cb10ca94cb5c4e0",
#     "text": "It is expected that the testers execute all the scripts in each of the cycles described above.",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "It is expected that the testers execute all the scripts in each of the cycles described above."
#       ],
#       "emphasized_text_tags": [
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "977e001dc6029e386c99904e48aa9226",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "301f464875b364366b16eac8dd80331a",
#     "text": "The defects will be tracked through Defect Tracker or Spreadsheet.",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "The defects will be tracked through Defect Tracker",
#         "or",
#         "S",
#         "preadsheet."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "977e001dc6029e386c99904e48aa9226",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "a818d702c72adf4fab3b99c3b7f8a384",
#     "text": "It is the responsibility of the tester to open the defects, retest and close the defect.",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "It is the responsibility of the tester to open the defects",
#         ",",
#         "retest and close the defect",
#         "."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "977e001dc6029e386c99904e48aa9226",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "1137858479668ef6d117ccae1467712c",
#     "text": "Defects found during the Testing should be categorized as below:\t",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "da239340b265ec3de6ddbfa1f375015c",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "e59a8d852fe5574a1cad5bb68cbd0f4f",
#     "text": "Severity Impact 1 (Critical) Functionality is blocked and no testing can proceed Application/program/feature is unusable in the current state 2 (High) Functionality is not usable and there is no workaround but testing can proceed 3 (Medium) Functionality issues but there is workaround for achieving the desired functionality 4 (Low) Unclear error message or cosmetic error which has minimum impact on product use.",
#     "metadata": {
#       "emphasized_text_contents": [
#         "Severity",
#         "Impact",
#         "1 (Critical)",
#         "Functionality is blocked and no testing can proceed",
#         "Application/program/feature is unusable in the current state",
#         "2 (High)",
#         "Functionality is not usable and there is no workaround but testing can proceed",
#         "3 (Medium)",
#         "Functionality issues but there is",
#         "workaround for achieving",
#         "the desired functionality",
#         "4 (Low)",
#         "Unclear error message or cosmetic error",
#         "which has minimum impact on product use."
#       ],
#       "emphasized_text_tags": [
#         "b",
#         "b",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "text_as_html": "<table>\n<thead>\n<tr><th>Severity    </th><th>Impact                                                                              </th></tr>\n</thead>\n<tbody>\n<tr><td>1 (Critical)</td><td>Functionality is blocked and no testing can proceed\nApplication/program/feature is unusable in the current state                                                                                     </td></tr>\n<tr><td>2 (High)    </td><td>Functionality is not usable and there is no workaround but testing can proceed      </td></tr>\n<tr><td>3 (Medium)  </td><td>Functionality issues but there is workaround for achieving the desired functionality</td></tr>\n<tr><td>4 (Low)     </td><td>Unclear error message or cosmetic error which has minimum impact on product use.    </td></tr>\n</tbody>\n</table>",
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "da239340b265ec3de6ddbfa1f375015c",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "5ee43e01ad9383ca3509acb67824957d",
#     "text": "Environment Requirements",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "2187e624e5dac15b2a51db656dc573e7",
#     "text": "  Test Environments",
#     "metadata": {
#       "category_depth": 1,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "5ee43e01ad9383ca3509acb67824957d",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "e92ce9913ef469feb05650ef6ad8f19a",
#     "text": "Specify the test environment(s) requirements",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Specify",
#         "the",
#         "test environment",
#         "(s) requirements"
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "2187e624e5dac15b2a51db656dc573e7",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "9c160b16c0a77b0005a490238445b30a",
#     "text": "Specify the security requirements.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "S",
#         "pecify the security",
#         "requirements."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "2187e624e5dac15b2a51db656dc573e7",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "2f7d8f4488fe96807702d20260129166",
#     "text": "Significantly Impacted Division/College/Department",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "721cc152bdeec5f654daaa810a999968",
#     "text": "Business Area Business Manager Tester(s)",
#     "metadata": {
#       "emphasized_text_contents": [
#         "Business Area",
#         "Business Manager",
#         "Tester(s)"
#       ],
#       "emphasized_text_tags": [
#         "b",
#         "b",
#         "b"
#       ],
#       "page_number": 1,
#       "text_as_html": "<table>\n<thead>\n<tr><th>Business Area  </th><th>Business Manager  </th><th>Tester(s)  </th></tr>\n</thead>\n<tbody>\n<tr><td>               </td><td>                  </td><td>           </td></tr>\n<tr><td>               </td><td>                  </td><td>           </td></tr>\n<tr><td>               </td><td>                  </td><td>           </td></tr>\n</tbody>\n</table>",
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "2f7d8f4488fe96807702d20260129166",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "2e41b118eb209c139f2bcbf690486f6e",
#     "text": "Dependencies",
#     "metadata": {
#       "category_depth": 0,
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "95a5ad919c15e641149a77cf3ccd67a4",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ebc61ba46583d685ef14638022adbcb0",
#     "text": "Identify any dependencies on testing, such as test-item availability, testing-resource availability, and deadlines.",
#     "metadata": {
#       "category_depth": 0,
#       "emphasized_text_contents": [
#         "Identify",
#         "any dependencies",
#         "on testing, such as test-item availability, testing-resource availability, and deadlines."
#       ],
#       "emphasized_text_tags": [
#         "i",
#         "i",
#         "i"
#       ],
#       "page_number": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "2e41b118eb209c139f2bcbf690486f6e",
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   },
#   {
#     "type": "Footer",
#     "element_id": "b629a3c4ef2e76849f7079496c86a0fc",
#     "text": "Test Plan Template",
#     "metadata": {
#       "category_depth": 0,
#       "header_footer_type": "primary",
#       "languages": [
#         "eng"
#       ],
#       "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#     }
#   }
# ]

# %%
from IPython.display import JSON    

JSON(example_output)
# Out:
# /Users/parikshitmehta/Knowledge_Graph_RAG/kgvenv/lib/python3.10/site-packages/IPython/core/display.py:618: UserWarning: JSON expects JSONable dict or list, not JSON strings
#   warnings.warn("JSON expects JSONable dict or list, not JSON strings")

# %%
import docx

from unstructured.partition.docx import partition_docx

document = docx.Document()
document.add_paragraph("Important Analysis", style="Heading 1")
document.add_paragraph("Here is my first thought.", style="Heading 2")
document.add_paragraph("Here is my second thought.", style="Normal")
document.save("temp_data/mydoc.docx")

elements = partition_docx(filename="temp_data/mydoc.docx")

with open("mydoc.docx", "rb") as f:
    elements = partition_docx(file=f)

# %%
print(json.dumps([el.to_dict() for el in elements], indent=8))
# Out:
# [
#         {
#                 "type": "Title",
#                 "element_id": "f2188a093c11fdf207581da97c57f55e",
#                 "text": "Important Analysis",
#                 "metadata": {
#                         "category_depth": 0,
#                         "languages": [
#                                 "eng"
#                         ],
#                         "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#                 }
#         },
#         {
#                 "type": "NarrativeText",
#                 "element_id": "996cdc8d4c0c99fa854de867641d7d9c",
#                 "text": "Here is my first thought.",
#                 "metadata": {
#                         "category_depth": 0,
#                         "languages": [
#                                 "eng"
#                         ],
#                         "parent_id": "f2188a093c11fdf207581da97c57f55e",
#                         "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#                 }
#         },
#         {
#                 "type": "NarrativeText",
#                 "element_id": "5a84813ae7e3e16613b6d7f9fd12c6a8",
#                 "text": "Here is my second thought.",
#                 "metadata": {
#                         "category_depth": 0,
#                         "languages": [
#                                 "eng"
#                         ],
#                         "parent_id": "f2188a093c11fdf207581da97c57f55e",
#                         "filetype": "application/vnd.openxmlformats-officedocument.wordprocessingml.document"
#                 }
#         }
# ]

# %%
from docx import Document
import json

def read_docx(filename):
    doc = Document(filename)
    data = []

    for paragraph in doc.paragraphs:
        item = {'type': 'paragraph', 'content': paragraph.text}
        data.append(item)

    for section in doc.sections:
        item = {'type': 'section', 'page_number': section.start_page_number}
        data.append(item)

    for paragraph in doc.paragraphs:
        if paragraph.style.name.startswith('Heading'):
            item = {'type': 'heading', 'level': int(paragraph.style.name[-1]), 'content': paragraph.text}
            data.append(item)

    return data

def convert_to_json(filename, json_filename):
    data = read_docx(filename)
    with open(json_filename, 'w') as f:
        json.dump(data, f, indent=4)

# Usage example
convert_to_json('temp_data/output_V2.docx', 'temp_data/output.json')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 29
#      26         json.dump(data, f, indent=4)
#      28 # Usage example
# ---> 29 convert_to_json('temp_data/output_V2.docx', 'temp_data/output.json')
#
# Cell In[52], line 24, in convert_to_json(filename, json_filename)
#      23 def convert_to_json(filename, json_filename):
# ---> 24     data = read_docx(filename)
#      25     with open(json_filename, 'w') as f:
#      26         json.dump(data, f, indent=4)
#
# Cell In[52], line 13, in read_docx(filename)
#      10     data.append(item)
#      12 for section in doc.sections:
# ---> 13     item = {'type': 'section', 'page_number': section.start_page_number}
#      14     data.append(item)
#      16 for paragraph in doc.paragraphs:
#
# AttributeError: 'Section' object has no attribute 'start_page_number'

# %%
from docx.shared import Pt
filename = 'temp_data/output_V3.docx'
doc = Document(filename)

doc.add_heading('GeeksForGeeks', 0) 
  
# Adding paragraph with Increased font size 
doc.add_heading('Increased Font Size Paragraph:', 3) 
para = doc.add_paragraph().add_run( 
    'GeeksforGeeks is a Computer Science portal for geeks.') 
# Increasing size of the font 
para.font.size = Pt(12) 
  
# Adding paragraph with normal font size 
doc.add_heading('Normal Font Size Paragraph:', 3) 
doc.add_paragraph( 
    'GeeksforGeeks is a Computer Science portal for geeks.') 

data = []

for paragraph in doc.paragraphs:
    item = {'type': 'paragraph', 'content': paragraph.text}
    data.append(item)

headings =[]
for paragraph in doc.paragraphs:
    for run in paragraph.runs:
        font = run.font
        print(font.size)
        if run.bold:
            headings.append(paragraph.text)
    if paragraph.style.name == "Heading 2":
        headings.append(paragraph.text)
        
print(headings)
for paragraph in doc.paragraphs:
    if paragraph.style.name.startswith('Heading'):
        print(paragraph.style.name)
        item = {'type': 'heading', 'level': int(paragraph.style.name[-1]), 'content': paragraph.text}
        data.append(item)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 152400
# None
# None
# []
# Heading 1
# Heading 3
# Heading 3

# %%
data
# Out:
# [{'type': 'paragraph', 'content': 'Summary'},
#  {'type': 'paragraph',
#   'content': 'Linkin Park is an American rock band from Agoura Hills, California. The band\'s lineup consists of vocalist/rhythm guitarist/keyboardist Mike Shinoda, lead guitarist Brad Delson, bassist Dave Farrell, DJ/turntablist Joe Hahn, and drummer Rob Bourdon, with vocalist Chester Bennington also part of the band until his death in 2017. Categorized as alternative rock, Linkin Park\'s earlier music spanned a fusion of heavy metal and hip hop, while their later music features more electronica and pop elements.\nFormed in 1996, Linkin Park rose to international fame with their debut studio album, Hybrid Theory (2000), which became certified Diamond by the Recording Industry Association of America (RIAA). Released during the peak of the nu metal scene, the album\'s singles\' heavy airplay on MTV led the singles "One Step Closer", "Crawling", and "In the End" all to chart highly on the US Mainstream Rock chart. The lattermost also crossed over to the #2 spot on the nation\'s Billboard Hot 100. Their second album, Meteora (2003), continued the band\'s success. The band explored experimental sounds on their third album, Minutes to Midnight (2007). By the end of the decade, Linkin Park was among the most successful and popular rock acts.\n'},
#  {'type': 'paragraph',
#   'content': "The band continued to explore a wider variation of musical types on their fourth album, A Thousand Suns (2010), layering their music with more electronic sounds. The band's fifth album, Living Things (2012), combined musical elements from all of their previous records. Their sixth album, The Hunting Party (2014), returned to a heavier rock sound, while their seventh album, One More Light (2017), was a substantially more pop-oriented record. Linkin Park went on an indefinite hiatus following the suicide of longtime lead vocalist Bennington in July 2017 and have not recorded or toured since then. Since Bennington's death, they have only released 20th-anniversary editions of their first two studio albums, as well as a greatest hits album, Papercuts, in 2024.\n"},
#  {'type': 'paragraph',
#   'content': 'Linkin Park is among both the best-selling bands of the 21st century and the world\'s best-selling music artists, having sold over 100 million records worldwide. They have won two Grammy Awards, six American Music Awards, two Billboard Music Awards, four MTV Video Music Awards, 10 MTV Europe Music Awards, and three World Music Awards. In 2003, MTV2 named Linkin Park the sixth-greatest band of the music video era and the third-best of the new millennium. Billboard ranked Linkin Park No. 19 on the Best Artists of the Decade list. In 2012, the band was voted as the greatest artist of the 2000s in a Bracket Madness poll on VH1. In 2014, the band was declared as "The Biggest Rock Band in the World Right Now" by Kerrang!.'},
#  {'type': 'paragraph', 'content': '\n\n'},
#  {'type': 'paragraph', 'content': 'History'},
#  {'type': 'paragraph', 'content': '1996–2000: early years\n'},
#  {'type': 'paragraph',
#   'content': 'Linkin Park was founded by three high school friends: Mike Shinoda, Rob Bourdon, and Brad Delson. The three attended Agoura High School in Agoura Hills, California, a suburb of Los Angeles. After graduating from high school, the three began to take their musical interests more seriously, recruiting Joe Hahn, Dave "Phoenix" Farrell, and Mark Wakefield to perform in their band, then called Xero. Though limited in resources, the band began recording and producing songs within Shinoda\'s makeshift bedroom studio in 1996, resulting in a four-track demo album, entitled Xero, released in November 1997. Xero performed their first show on November 14, opening for SX-10 and System of a Down at the Whisky a Go Go, a nightclub in West Hollywood. Delson introduced the band to Jeff Blue, the vice president of A&R for Zomba Music, whom he had interned for in college. Blue offered the band constructive criticism to catch the attention of record labels. Blue himself was impressed with Xero after watching them play a live show in 1998, but believed the band needed a different vocalist. Tensions and frustration within the band grew after they failed to land a record deal. The lack of success and stalemate in progress prompted Wakefield, at that time the band\'s vocalist, to leave the band in search of other projects. Farrell also left to tour with Tasty Snax, a Christian punk and ska band.'},
#  {'type': 'paragraph',
#   'content': '\nAfter spending a considerable time searching for Wakefield\'s replacement, Xero recruited Arizona vocalist Chester Bennington, who was recommended by Jeff Blue in March 1999. Bennington, formerly of a post-grunge band Grey Daze, became a standout among applicants because of the dynamic in his singing style. The band then agreed on changing their name from Xero to Hybrid Theory; the newborn vocal chemistry between Shinoda and Bennington helped revive the band, inciting them to work on new material. Additionally, the band recruited bassist Kyle Christner to temporarily fill in for Farrell. In May 1999, the band released a self-titled extended play, which they circulated across internet chat-rooms and forums with the help of an online "street team". In October 1999, Christner was replaced by Scott Koziol and Ian Hornbeck, whom along with Delson, provided bass tracks for the band\'s recordings.'},
#  {'type': 'paragraph',
#   'content': '\nThe band still struggled to sign a record deal. They turned to Jeff Blue for additional help after facing numerous rejections from several major record labels. After failing to catch Warner Bros. Records on three previous reviews, Blue, who was now the vice president of Warner Bros. Records, helped the band sign a deal with the company as a developing artist in 1999. However, the label advised the band to change their name to avoid confusion with Hybrid. The band considered the names "Plear" and "Platinum Lotus Foundation" before deciding on "Linkin Park", a play on and homage to Santa Monica\'s Lincoln Park, now called Christine Emerson Reed Park. They initially wanted to use the name "Lincoln Park", however they changed it to "Linkin" to acquire the internet domain "linkinpark.com".\nBennington and Shinoda both reported that Warner Bros. Records was skeptical of Linkin Park\'s initial recordings. The label\'s A&R was not pleased with the band\'s hip-hop and rock-style approach. An A&R representative suggested that Bennington should demote or fire Shinoda and exclusively focus on making a rock record. Bennington supported Shinoda and refused to compromise Linkin Park\'s vision for the album. Farrell returned in late 2000, and the band released their breakthrough album, Hybrid Theory, that same year.\n\n2000–2002: Hybrid Theory and Reanimation\nLinkin Park released Hybrid Theory on October 24, 2000. The album, which represented half a decade\'s worth of the band\'s work, was edited by Don Gilmore. Hybrid Theory was a massive commercial success; it sold more than 4.8 million copies during its debut year, earning it the status of best-selling album of 2001. Singles such as "Crawling" and "One Step Closer" established themselves as staples among alternative rock radio play lists during the year, and "In the End" peaked at #2 on the US Billboard Hot 100, the band\'s highest to date. Additionally, other singles from the album were featured in films such as Dracula 2000, Little Nicky, and Valentine. Hybrid Theory won a Grammy Award for Best Hard Rock Performance for the song "Crawling" and was nominated for two other Grammy Awards: Best New Artist and Best Rock Album. MTV awarded the band their Best Rock Video and Best Direction awards for "In the End".\nDuring this time, Linkin Park received many invitations to perform on many high-profile tours and concerts including Ozzfest, Family Values Tour, and KROQ Almost Acoustic Christmas. The band worked with Jessica Sklar to found their official fan club and street team, "Linkin Park Underground", in November 2001. Linkin Park also formed their own tour, Projekt Revolution, which featured other artists such as Cypress Hill, Adema, and Snoop Dogg. Within a year\'s stretch, Linkin Park had performed at over 320 concerts. The experiences and performances of the precocious band were documented in their first DVD, Frat Party at the Pankake Festival, which debuted in November 2001. Now reunited with former bassist Phoenix, the band began work on a remix album, dubbed Reanimation, which would include works from Hybrid Theory and non-album tracks. Reanimation debuted on July 30, 2002, featuring the likes of Black Thought, Jonathan Davis, Aaron Lewis, and many others. Reanimation claimed the second spot on the Billboard 200, and sold nearly 270,000 copies during its debut week. Hybrid Theory is also in the RIAA\'s Top 100 Albums.\n'},
#  {'type': 'paragraph', 'content': '\n2002–2004: Meteora\n'},
#  {'type': 'paragraph',
#   'content': 'Following the success of Hybrid Theory and Reanimation, Linkin Park spent a significant amount of time touring around the United States. The band members began to work on new material amidst their saturated schedule, spending a sliver of their free time in their tour bus\'s studio. The band officially announced the production of a new studio album in December 2002, revealing their new work was inspired by the rocky region of Meteora in Greece, where numerous monasteries have been built on top of the rocks. Meteora features a mixture of the band\'s nu metal and rap metal style with newer innovative effects, including the induction of a shakuhachi (a Japanese flute made of bamboo) and other instruments. Linkin Park\'s second album debuted on March 25, 2003, and instantly earned worldwide recognition, peaking at No. 1 on the Rock & Metal Albums Chart.\nMeteora sold more than 800,000 copies during its first week, and it ranked as the best selling album on the Billboard charts at the time. The album\'s singles, including "Somewhere I Belong", "Breaking the Habit", "Faint", and "Numb", received significant radio attention. By October 2003, Meteora sold nearly three million copies. The album\'s success allowed Linkin Park to form another Projekt Revolution, which featured other bands and artists including Mudvayne, Blindside, and Xzibit. Additionally, Metallica invited Linkin Park to play at the Summer Sanitarium Tour 2003, which included well-known acts such as Limp Bizkit, Mudvayne and Deftones. The band released an album and DVD, titled Live in Texas, which featured some audio and video tracks from the band\'s performances in Texas during the tour. In early 2004, Linkin Park started a world tour titled the Meteora World Tour. Supporting bands on the tour included Hoobastank, P.O.D., and Story of the Year.'},
#  {'type': 'paragraph',
#   'content': '\nMeteora earned the band multiple awards and honors. The band won the MTV awards for Best Rock Video for "Somewhere I Belong" and the Viewer\'s Choice Award for "Breaking the Habit". Linkin Park also received significant recognition during the 2004 Radio Music Awards, winning the Artist of the Year and Song of the Year ("Numb") awards. Although Meteora was not nearly as successful as Hybrid Theory, it was the third best selling album in the United States during 2003. The band spent the first few months of 2004 touring around the world, first with the third Projekt Revolution tour, and later several European concerts. At the same time, the band\'s relationship with Warner Bros. Records was deteriorating rapidly on account of several trust and financial issues. After months of feuding, the band finally negotiated a deal in December 2005.\n'},
#  {'type': 'paragraph',
#   'content': '2004–2006: side project\nFollowing Meteora\'s success, the band worked on many side projects. Bennington appeared on DJ Lethal\'s "State of the Art" and other work with Dead by Sunrise, while Shinoda did work with Depeche Mode, creating the remix song "Enjoy the Silence 04". In 2004, the band began to work with Jay-Z to produce another remix album, titled Collision Course. The album, which featured intermixed lyrics and background tracks from both artists\' previous albums, debuted in November 2004. Shinoda also formed Fort Minor as a side project. With the aid of Jay-Z, Fort Minor released their debut album, The Rising Tied, to critical acclaim.\nLinkin Park also participated in numerous charitable events, which included raising money to benefit victims of Hurricane Charley in 2004 and later Hurricane Katrina in 2005. The band donated $75,000 to the Special Operations Warrior Foundation in March 2004. They also helped relief efforts for the 2004 Indian Ocean tsunami victims by staging several charity concerts and setting up an additional fund called Music for Relief. The band participated at Live 8, a series of charitable benefit concerts set up to raise global awareness. Alongside Jay-Z, the band performed on Live 8\'s stage in Philadelphia, Pennsylvania, to a global audience. The band would later be reunited with Jay-Z at the Grammy Award Ceremony 2006, during which they performed "Numb/Encore", en route to winning a Grammy for Best Rap/Sung Collaboration. They were joined on stage by Paul McCartney who added verses from the song "Yesterday". They would later go on to play at the 2006 Summer Sonic music festival, which was hosted by Metallica in Japan.'},
#  {'type': 'paragraph',
#   'content': "2006–2008: Minutes to Midnight\nLinkin Park returned to the recording studios in 2006 to work on new material. To produce the album, the band chose producer Rick Rubin. Despite initially stating the album would debut sometime in 2006, the album was delayed until 2007. The band had recorded thirty to fifty songs in August 2006, when Shinoda stated the album was halfway completed. Bennington later added that the new album would stray away from their previous nu metal sound. Warner Bros. Records officially announced that the band's third studio album, titled Minutes to Midnight, would be released on May 15, 2007, in the United States. After spending fourteen months working on the album, the band members opted to further refine their album by removing five of the original seventeen tracks. The album's title, a reference to the Doomsday Clock, foreshadowed the band's new lyrical themes. Minutes to Midnight sold over 623,000 copies in its first week, making it one of the most successful debut week albums in recent years. The album also took the top spot on the Billboard Charts."},
#  {'type': 'paragraph',
#   'content': 'The album\'s first single, "What I\'ve Done", was released on April 2, and premiered on MTV and Fuse within the same week. The single peaked at no. 7 on the Billboard Hot 100. The song is also used in soundtrack for the 2007 action film, Transformers. Mike Shinoda was also featured on the Styles of Beyond song "Second to None", which was also included in the film. Later in the year, the band won the "Favorite Alternative Artist" in the American Music Awards. The band also saw success with the rest of the album\'s singles, "Bleed It Out", "Shadow of the Day", "Given Up", and "Leave Out All the Rest", which were released throughout 2007 and early 2008. The band also collaborated with Busta Rhymes on his single "We Made It", which was released on April 29.'},
#  {'type': 'paragraph',
#   'content': 'Linkin Park embarked on a large world tour titled "Minutes to Midnight World Tour". The band promoted the album\'s release by forming their fourth Projekt Revolution tour in the United States which included many musical acts like My Chemical Romance, Taking Back Sunday, HIM, Placebo, and many others. They also played numerous shows in Europe, Asia, and Australia which included a performance at Live Earth Japan on July 7, 2007. and headlining Download Festival in Donington Park, England and Edgefest in Downsview Park, Toronto, Ontario, Canada. The band completed touring on their fourth Projekt Revolution tour before taking up an Arena tour around the United Kingdom, visiting Nottingham, Sheffield and Manchester, before finishing on a double night at the O2 arena in London. Bennington stated that Linkin Park plans to release a follow-up album to Minutes to Midnight. However, he stated the band will first embark on a United States tour to gather inspiration for the album. Linkin Park embarked on another Projekt Revolution tour in 2008. The United States Projekt Revolution tour featured Chris Cornell, the Bravery, Ashes Divide, Street Drum Corps and many others. Mike Shinoda announced a live CD/DVD titled Road to Revolution: Live at Milton Keynes, which is a live video recording from the Projekt Revolution gig at the Milton Keynes Bowl on June 29, 2008, which was officially released on November 24, 2008.'},
#  {'type': 'paragraph',
#   'content': '\n2008–2011: A Thousand Suns\nIn May 2009, Linkin Park announced they were working on a fourth studio album, which was planned to be released in 2010. Shinoda told IGN that the new album would be \'genre-busting,\' while building off of elements in Minutes to Midnight. He also mentioned that the album would be more experimental and "hopefully more cutting-edge". Bennington also addressed the media to confirm that Rick Rubin would return to produce the new album. The band later revealed the album would be called A Thousand Suns. While working on the new album, Linkin Park worked with successful film composer Hans Zimmer to produce the score for Transformers: Revenge of the Fallen. The band released a single for the movie, titled "New Divide". Joe Hahn created a music video for the song, which featured clips from the film. On June 22, Linkin Park played a short set in Westwood Village after the premier of the movie. After completing work for Transformers: Revenge of the Fallen, the band returned to the studio to finalize their album.'},
#  {'type': 'paragraph',
#   'content': '\nOn April 26, the band released an app for the iPhone, iPod Touch, and iPad, a game called 8-Bit Rebellion! It featured the band as playable characters, and a new song called "Blackbirds" which was unlockable by beating the game. The song was also later released as an iTunes bonus track on A Thousand Suns.'},
#  {'type': 'paragraph',
#   'content': 'A Thousand Suns was released on September 14. The album\'s first single, "The Catalyst", was released on August 2. The band promoted their new album by launching a concert tour, which started on October 2010. Other singles from the album include, "Waiting for the End", "Burning in the Skies", and "Iridescent". Furthermore, a documentary about the album\'s production, titled Meeting of A Thousand Suns, was available. On August 31, 2010, it was announced that the band would perform "The Catalyst" live for the first time at the 2010 MTV Video Music Awards on September 12, 2010. The venue of the debut live performance of the single was Griffith Observatory, an location used in Hollywood movies.\nLinkin Park reached No.9 in the Billboard Social 50, a chart of the most active artists on the world\'s leading social networking sites. In other Billboard Year-End charts, the band reached No.92 in the "Top Artists" chart, as well as A Thousand Suns reaching No.53 in the Year-End chart of the Billboard Top 200 albums and "The Catalyst" reaching No.40 in the Year-End Rock Songs chart.\nThe band was nominated for six Billboard Awards in 2011 for Top Duo or Group, Best Rock Album for A Thousand Suns, Top Rock Artist, Top Alternative Artist, Top Alternative Song for "Waiting for the End" and Top Alternative Album for A Thousand Suns, but did not win any award. The band charted in numerous Billboard Year-End charts in 2011. The band was No.39 in the Top Artists Chart, No.87 in the Billboard 200 Artists chart, No.11 in the Social 50 Chart, No.6 in the Top Rock Artists Chart, No.9 in the Rock Songs Artists Chart, No.16 in the Rock Albums Chart, No.4 in the Hard Rock Albums Chart, and No.7 in the Alternative Songs Chart.'},
#  {'type': 'paragraph',
#   'content': '2011–2013: Living Things and Recharged\nIn July 2011, Bennington told Rolling Stone that Linkin Park aims to produce a new album every eighteen months, and that he would be shocked if a new album did not come out in 2012. He later revealed in another interview in September 2011 that the band was still in the beginning phases of the next album, saying "We just kind of began. We like to keep the creative juices flowing, so we try to keep that going all the time ... we like the direction that we\'re going in". On March 28, 2012, Shinoda confirmed that the band is filming a music video for "Burn It Down", directed by Joe Hahn. Shinoda spoke to Co.Create about the album\'s art, saying that it will "blow them [the fans] away ... the average person is not going to be able to look at it and go, I understand that that\'s completely new, like not just the image but the way they made the image is totally new. So there\'s going to be that".\nIn April 2012, the band announced that Living Things would be the title of their fifth album and called it a "return to form". Shinoda stated that they chose the title Living Things because the album is more about people, personal interactions, and it is far more personal than their previous albums. The album\'s lead single, "Burn It Down", was released on April 16. The band promoted the album on the 2012 edition of the Honda Civic Tour, with co-headliners Incubus. Other singles from the album include "Lost in the Echo", "Powerless", and Castle of Glass". The band performed "Burn It Down" at 2012 Billboard Music Awards. On May 25, the band released the music video for "Burn It Down" and debuted "Lies Greed Misery", another song from Living Things. "Powerless", the twelfth and closing track of the album, was featured in the closing credits of the film Abraham Lincoln: Vampire Hunter.\nLiving Things was released on June 26 in the United States. The album sold over 223,000 copies during its debut week, ranking No. 1 on the US Albums Charts. Linkin Park\'s single "Castle of Glass" was nominated for \'Best Song in a Game\' at the 2012 Spike Video Game Awards. The band also performed at the award ceremony on December 7, but lost the award to "Cities" by Beck. Linkin Park also played at the Soundwave music festival in Australia, where they shared the stage with Metallica, Paramore, Blink-182, and Sum 41.\nOn August 10, 2013, the band collaborated with American musician Steve Aoki to record the song "A Light That Never Comes" for Linkin Park\'s online puzzle-action game LP Recharge (short for Linkin Park Recharge), which was launched on Facebook and the official LP Recharge website on September 12, 2013. The song would later be included on a remix album, entitled Recharged, which was released on October 29, 2013. Similar to Reanimation, the album features remixes of ten of the songs from Living Things, with contributions from other artists, such as Pusha T, Datsik, KillSonik, Bun B, Money Mark, and Rick Rubin. The band also worked on the soundtrack for the film Mall, which was directed by Joe Hahn.\n\n2013–2015: The Hunting Party\nIn an interview with Fuse, Shinoda confirmed that Linkin Park had begun recording their sixth studio album in May 2013. The band released the first single from their upcoming album, titled, "Guilty All the Same" (featuring Rakim) on March 6, 2014, through Shazam. The single was later released on the following day by Warner Bros. Records and debut at No. 27 on the US Billboard Rock Airplay charts before peaking at No. 1 on the Mainstream Rock charts in the following weeks. Shortly after the single\'s release, the band revealed their sixth album would be titled The Hunting Party. The album was produced by Shinoda and Delson, who wanted to explore musical elements from Hybrid Theory and the band\'s earlier material. Shinoda commented the album is a "90s style of rock record". He elaborated, "It\'s a rock record. It\'s loud and it\'s rock, but not in the sense of what you\ ...
#  {'type': 'paragraph', 'content': ''},
#  {'type': 'paragraph',
#   'content': 'Additional Information\nBand members\nTimeline\n\nGallery\nDiscography\nStudio albums\n\nHybrid Theory (2000)\nMeteora (2003)\nMinutes to Midnight (2007)\nA Thousand Suns (2010)\nLiving Things (2012)\nThe Hunting Party (2014)\nOne More Light (2017)\n\nAwards and nominations\nConcert tours\nHeadlining\n\nHybrid Theory World Tour (2001)\nProjekt Revolution (2002–2008, 2011)\nLP Underground Tour (2003)\nMeteora World Tour (2004)\nMinutes to Midnight World Tour (2007–08)\nInternational Tour (2009)\nA Thousand Suns World Tour (2010–11)\nLiving Things World Tour (2012–13)\nThe Hunting Party Tour (2014–15)\nOne More Light World Tour (2017)\nLinkin Park and Friends: Celebrate Life in Honor of Chester Bennington (2017)\nCo-headlining\n\n11th Annual Honda Civic Tour (2012)\nCarnivores Tour (with Thirty Seconds to Mars) (2014)\n\nSee also\nList of best-selling music artists\nList of best-selling albums\nList of best-selling remix albums\nList of best-selling singles\nList of best-selling albums in the United States\nList of songs recorded by Linkin Park\nList of artists who reached number one on the U.S. alternative rock chart\n\nNotes\nReferences\nExternal links\n\nOfficial website \nmusicforrelief.org'},
#  {'type': 'heading', 'level': 1, 'content': 'Summary'}]
